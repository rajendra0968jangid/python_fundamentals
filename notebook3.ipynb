# %%
print("hello")
# Out:
# hello

# %% [markdown]
# **Example Program**

# %%
#Find the length of a given string without using the len() function
s = input('Enter the string:')
counter = 0
for i in s:
  counter += 1
print('Length of string:',counter)
# Out:
# Enter the string:hello india
# Length of string: 11

# %%
#Extract username from a given email
#Eg if the email is aicodecenter@gmail.com
# then the username should be aicodecenter
s = input('Enter the email:')
term = s.index('@gmail.com')
print(s[0:term])
# Out:
# Enter the email:aicodecenter@gmail.com
# aicodecenter

# %%
# Count the frequency of a particular character in a provided string.
#Eg. 'hello how are you' is the string. the frequency of h in this string is 2
s = input('Enter the string:')
term = input('What would your search:')
counter = 0
for i in s:
  if term == i:
    counter += 1
print(counter)
# Out:
# Enter the string:hello hello hello
# What would your search:h
# 3

# %%
# Write a program which can remove a particular character from a string
s = input('Enter the string:')
term = input('What would like to remove:')
result = ''
for i in s:
  if i != term:
    result += i
print(result)
# Out:
# Enter the string:aicodecenter aicodecenter
# What would like to remove:e
# aicodcntr aicodcntr

# %%
# Write a program that can check whether a given string  is palindrome or not.
#madam
#malayalam
s = input('Enter the string:')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i - 1]:
    flag = False
    print('Not Palindrome')
    break
if flag:
  print("Palindrome")
# Out:
# Enter the string:madam
# Palindrome

# %%
# Write a program to count the number of words in a string without split().

# method 1
s = input('Enter the string:')
L = []
temp = ''
for i in s:
  if i != ' ':
    temp += i
  else:
    L.append(temp)
    temp = ''
print(L)
# Out:
# Enter the string:hi how are you
# ['hi', 'how', 'are']

# %%
# Write a python program to convert a string to title case without using the title()
s = input('Enter the String:')
L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())
print(" ".join(L))
# Out:
# Enter the String:Hello AICocenter
# Hello Aicocenter

# %%
# Write a program that can convert an interger to string
number = int(input('Enter the number:'))
digits = "0123456789"
